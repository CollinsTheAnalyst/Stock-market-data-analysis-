# %%
import pandas as pd

# %%
apple = pd.read_csv(r"C:\Users\USER\Downloads\Stocks Data\stocks\AAPL.csv")

# %%
apple
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.513393    0.515625    0.513393    0.513393    0.406782
# 1     1980-12-15    0.488839    0.488839    0.486607    0.486607    0.385558
# 2     1980-12-16    0.453125    0.453125    0.450893    0.450893    0.357260
# 3     1980-12-17    0.462054    0.464286    0.462054    0.462054    0.366103
# 4     1980-12-18    0.475446    0.477679    0.475446    0.475446    0.376715
# ...          ...         ...         ...         ...         ...         ...
# 9904  2020-03-26  246.520004  258.679993  246.360001  258.440002  258.440002
# 9905  2020-03-27  252.750000  255.869995  247.050003  247.740005  247.740005
# 9906  2020-03-30  250.740005  255.520004  249.399994  254.809998  254.809998
# 9907  2020-03-31  255.600006  262.489990  252.000000  254.289993  254.289993
# 9908  2020-04-01  246.500000  248.720001  239.130005  240.910004  240.910004
#
#          Volume
# 0     117258400
# ...

# %%
Facebook = pd.read_csv(r"C:\Users\USER\Downloads\Stocks Data\stocks\FB.csv")

# %%
Facebook
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.230000
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   34.029999
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   31.000000
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   32.000000
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   33.029999
# ...          ...         ...         ...         ...         ...         ...
# 1975  2020-03-26  158.250000  164.000000  157.020004  163.339996  163.339996
# 1976  2020-03-27  158.199997  160.089996  154.750000  156.789993  156.789993
# 1977  2020-03-30  159.179993  166.750000  158.059998  165.949997  165.949997
# 1978  2020-03-31  165.479996  170.929993  164.199997  166.800003  166.800003
# 1979  2020-04-01  161.619995  164.149994  158.039993  159.600006  159.600006
#
#          Volume
# 0     573576400
# ...

# %%
Google = pd.read_csv(r"C:\Users\USER\Downloads\Stocks Data\stocks\GOOGL.csv")

# %%
Nvidia = pd.read_csv(r"C:\Users\USER\Downloads\Stocks Data\stocks\NVDA.csv")

# %%
Tesla = pd.read_csv(r"C:\Users\USER\Downloads\Stocks Data\stocks\TSLA.csv")

# %%
Twitter = pd.read_csv(r"C:\Users\USER\Downloads\Stocks Data\stocks\TWTR.csv")

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400

# %%
Twitter.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1  2013-11-08  45.930000  46.939999  40.689999  41.650002  41.650002
# 2  2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3  2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4  2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
#
#       Volume
# 0  117701600
# 1   27925300
# 2   16113900
# 3    6316700
# 4    8688300

# %%
Tesla.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
Nvidia.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1999-01-22  1.750000  1.953125  1.552083  1.640625   1.509998  67867200.0
# 1  1999-01-25  1.770833  1.833333  1.640625  1.812500   1.668188  12762000.0
# 2  1999-01-26  1.833333  1.869792  1.645833  1.671875   1.538759   8580000.0
# 3  1999-01-27  1.677083  1.718750  1.583333  1.666667   1.533965   6109200.0
# 4  1999-01-28  1.666667  1.677083  1.651042  1.661458   1.529172   5688000.0

# %%
Google.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  50.050049  52.082081  48.028027  50.220219  50.220219  44659000
# 1  2004-08-20  50.555557  54.594593  50.300301  54.209209  54.209209  22834300
# 2  2004-08-23  55.430431  56.796795  54.579578  54.754753  54.754753  18256100
# 3  2004-08-24  55.675674  55.855854  51.836838  52.487488  52.487488  15247300
# 4  2004-08-25  52.532532  54.054054  51.991993  53.053055  53.053055   9188600

# %%
dfs= [apple,Facebook,Google,Nvidia,Tesla,Twitter]

# %%
dfs
# Out:
# [            Date        Open        High         Low       Close   Adj Close  \
#  0     1980-12-12    0.513393    0.515625    0.513393    0.513393    0.406782
#  1     1980-12-15    0.488839    0.488839    0.486607    0.486607    0.385558
#  2     1980-12-16    0.453125    0.453125    0.450893    0.450893    0.357260
#  3     1980-12-17    0.462054    0.464286    0.462054    0.462054    0.366103
#  4     1980-12-18    0.475446    0.477679    0.475446    0.475446    0.376715
#  ...          ...         ...         ...         ...         ...         ...
#  9904  2020-03-26  246.520004  258.679993  246.360001  258.440002  258.440002
#  9905  2020-03-27  252.750000  255.869995  247.050003  247.740005  247.740005
#  9906  2020-03-30  250.740005  255.520004  249.399994  254.809998  254.809998
#  9907  2020-03-31  255.600006  262.489990  252.000000  254.289993  254.289993
#  9908  2020-04-01  246.500000  248.720001  239.130005  240.910004  240.910004
#
#           Volume
# ...

# %%
for df in dfs:
    df['MA50'] = df.Close.rolling(50).mean()
    df['MA200'] = df.Close.rolling(200).mean()

# %%
apple.head(220)
# Out:
#            Date      Open      High       Low     Close  Adj Close     Volume  \
# 0    1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1    1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2    1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3    1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4    1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
# ..          ...       ...       ...       ...       ...        ...        ...
# 215  1981-10-21  0.350446  0.352679  0.350446  0.350446   0.277673   19224800
# 216  1981-10-22  0.350446  0.350446  0.348214  0.348214   0.275904    8069600
# 217  1981-10-23  0.341518  0.341518  0.339286  0.339286   0.268830    6977600
# 218  1981-10-26  0.339286  0.341518  0.339286  0.339286   0.268830    6820800
# 219  1981-10-27  0.345982  0.350446  0.345982  0.345982   0.274135   21397600
#
#          MA50     MA200
# ...

# %%
for df in dfs:
    df['Previous day Close price'] = df.Close.shift(1)

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
#
#    MA50  MA200  Previous day Close price
# 0   NaN    NaN                       NaN
# 1   NaN    NaN                  0.513393
# 2   NaN    NaN                  0.486607
# 3   NaN    NaN                  0.450893
# 4   NaN    NaN                  0.462054

# %%
for df in dfs:
        df['Change in Price'] = df['Close'] - df['Previous day Close price']

# %%
apple.head(2)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
#
#    MA50  MA200  Previous day Close price  Change in Price
# 0   NaN    NaN                       NaN              NaN
# 1   NaN    NaN                  0.513393        -0.026786

# %%
for df in dfs:
    df['Percent change in price'] = df.Close.pct_change()

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
#
#    MA50  MA200  Previous day Close price  Change in Price  \
# 0   NaN    NaN                       NaN              NaN
# 1   NaN    NaN                  0.513393        -0.026786
# 2   NaN    NaN                  0.486607        -0.035714
# 3   NaN    NaN                  0.450893         0.011161
# 4   NaN    NaN                  0.462054         0.013393
#
#    Percent change in price
# 0                      NaN
# 1                -0.052174
# 2                -0.073394
# 3                 0.024752
# ...

# %%
for df in dfs:
    df['Previous day Volume'] = df.Volume.shift(1)

# %%
apple.head(2)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
#
#    MA50  MA200  Previous day Close price  Change in Price  \
# 0   NaN    NaN                       NaN              NaN
# 1   NaN    NaN                  0.513393        -0.026786
#
#    Percent change in price  Previous day Volume
# 0                      NaN                  NaN
# 1                -0.052174          117258400.0

# %%
for df in dfs:
    df['Change in volume'] = df['Volume'] - df['Previous day Volume']

# %%
apple.head(4)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
#
#    MA50  MA200  Previous day Close price  Change in Price  \
# 0   NaN    NaN                       NaN              NaN
# 1   NaN    NaN                  0.513393        -0.026786
# 2   NaN    NaN                  0.486607        -0.035714
# 3   NaN    NaN                  0.450893         0.011161
#
#    Percent change in price  Previous day Volume  Change in volume
# 0                      NaN                  NaN               NaN
# 1                -0.052174          117258400.0       -73287200.0
# 2                -0.073394           43971200.0       -17539200.0
# ...

# %%
for df in dfs:
    df['Percent change in Volume'] = df.Volume.pct_change()

# %%
apple.head(4)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
#
#    MA50  MA200  Previous day Close price  Change in Price  \
# 0   NaN    NaN                       NaN              NaN
# 1   NaN    NaN                  0.513393        -0.026786
# 2   NaN    NaN                  0.486607        -0.035714
# 3   NaN    NaN                  0.450893         0.011161
#
#    Percent change in price  Previous day Volume  Change in volume  \
# 0                      NaN                  NaN               NaN
# 1                -0.052174          117258400.0       -73287200.0
# 2                -0.073394           43971200.0       -17539200.0
# ...

# %%
apple.to_csv(r'C:\Users\USER\Downloads\Stocks Data\apple.csv')

# %%
Facebook.to_csv(r'C:\Users\USER\Downloads\Stocks Data\Facebook.csv')

# %%
Google.to_csv(r'C:\Users\USER\Downloads\Stocks Data\Google.csv')

# %%
Nvidia.to_csv(r'C:\Users\USER\Downloads\Stocks Data\Nvidia.csv')

# %%
Tesla.to_csv(r'C:\Users\USER\Downloads\Stocks Data\Tesla.csv')

# %%
Twitter.to_csv(r'C:\Users\USER\Downloads\Stocks Data\Twitter.csv')
